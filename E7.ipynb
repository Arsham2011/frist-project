# %%
# here's my imports

import pyautogui as siri

from deep_translator import GoogleTranslator as GT

from textblob import TextBlob as TB

# my variabels

a = input ( 'what do you want (if you want to translate type Translate or if you want get it feel type Feel and if you want to repeat it type Repeat):' )

# it's about my canceler 

if a == ' ' :
     
    print ( 'OK' )
 
# it's my translator part

elif a == 'Translate' or 'translate' :
    b = input ( 'give me your word or sentence:' )
    
    if b == ' ' :
    
        print ( 'OK' )

    b = GT ( source = 'auto' , target = 'en' ) . translate ( b )

    print ( b )

# there's my sensebility system

elif a == 'Feel' or 'feel' :
    
    b = input ( 'give me your word or sentence:' )
    
    b = GT ( source = 'auto' , target = 'en' ) . translate ( b )

    blob = TB ( b )

    f = blob . sentiment . polarity

    if b == ' ' :

        print ( 'OK' )

    elif f > 0 :

        print ( b )

        print ( 'pasetive' )

    elif f < 0 :

        print ( b )

        print ( 'negetive' )

    else :

        print ( b )

        print ( 'nothing' )

# and this is my string repeater codes

elif a == 'Repeat' or 'repeat' :
    
    b = input ( 'give me your word or sentence:' )
    
    if b == ' ' :
    
        print ( 'OK' )

    else :
        
        c = int ( input ( 'how many turn do you want to repeat?' ) )

        c = c + 1

        b = b + ' '

        with open( 'note.text','w', encoding = 'utf-8' ) as d :

            siri . sleep ( 1 )

            siri . click ( 200 , 755 )

            siri . sleep ( 0.3 )

            siri . click ( 600 , 300 )

            siri . sleep ( 0.3 )

            for x in range ( 1 , c ) :

                siri . write ( b , interval = 0.05 ) , siri . press ( 'enter' , interval = 0.05 )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 11
#       7 from textblob import TextBlob as TB
#       9 # my variabels
# ---> 11 a = input ( 'what do you want' , "\n" , '(if you want to translate type Translate or if you want get it feel type Feel and if you want to repeat it type Repeat):' )
#      13 # it's about my canceler
#      15 if a == ' ' :
#
# TypeError: Kernel.raw_input() takes from 1 to 2 positional arguments but 4 were given
